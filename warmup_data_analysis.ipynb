# %%
# !pip install underthesea
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 54.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 657.8/657.8 kB 48.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import underthesea

# %%
df = pd.read_json("ise-dsc01-warmup.json")

# %%
df = df.swapaxes(1,0)
df = df.reset_index()
df
# Out:
#      index                                            context
# 0    36112  Ở vòng này, độc giả VnExpress sẽ bình chọn cho...  \
# 1    27839  Cụ thể, thử nghiệm hôm 20/4 để lại một hố trũn...
# 2    36633  Từ 15h mỗi ngày, chị Trang, chủ hàng ốc bươu n...
# 3    18939  Ivanov, 22 tuổi, mơ thấy chỉ huy xe tăng của a...
# 4    19153  Sáng 2/2, kết luận phiên họp Chính phủ thường ...
# ..     ...                                                ...
# 995  46648  Điều khiến du khách ấn tượng khi ghé Bãi Bùi c...
# 996  13375  Charmaine Smigielski, 70 tuổi, đặt vé của hãng...
# 997  10840  Vận động viên chạy bộ người Bulgaria Krasse Gu...
# 998  15809  Ngày 14/2, thấy cánh đồng mía của hộ bên cạnh ...
# 999    881  Em là học sinh lớp 12, học các môn tự nhiên ở ...
#
#                                                  claim    verdict
# 0    Trong năm nay, hai địa phương dẫn đầu và gần n...  SUPPORTED  \
# 1                          FAA có hơn 10.000 nhân viên        NEI
# ...

# %%
df.to_csv("warmup.csv", escapechar='\\', index = False)

# %%
df["domain"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='domain'>

# %%
df["verdict"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='verdict'>

# %%
dfSta = df
dfSta["countWords"] = df["context"].apply(lambda x: len(x.split()))
dfSta["countSentences"] = df["context"].apply(lambda x: len(underthesea.sent_tokenize(x)))
dfSta
# Out:
#      index                                            context
# 0    36112  Ở vòng này, độc giả VnExpress sẽ bình chọn cho...  \
# 1    27839  Cụ thể, thử nghiệm hôm 20/4 để lại một hố trũn...
# 2    36633  Từ 15h mỗi ngày, chị Trang, chủ hàng ốc bươu n...
# 3    18939  Ivanov, 22 tuổi, mơ thấy chỉ huy xe tăng của a...
# 4    19153  Sáng 2/2, kết luận phiên họp Chính phủ thường ...
# ..     ...                                                ...
# 995  46648  Điều khiến du khách ấn tượng khi ghé Bãi Bùi c...
# 996  13375  Charmaine Smigielski, 70 tuổi, đặt vé của hãng...
# 997  10840  Vận động viên chạy bộ người Bulgaria Krasse Gu...
# 998  15809  Ngày 14/2, thấy cánh đồng mía của hộ bên cạnh ...
# 999    881  Em là học sinh lớp 12, học các môn tự nhiên ở ...
#
#                                                  claim    verdict
# 0    Trong năm nay, hai địa phương dẫn đầu và gần n...  SUPPORTED  \
# 1                          FAA có hơn 10.000 nhân viên        NEI
# ...

# %%
dfSta["countWords"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
dfSta["countSentences"].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>
